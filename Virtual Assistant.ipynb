# %%
import json 
import string 
import random
import nltk 
import numpy as np
from nltk.stem import WordNetLemmatizer
import tensorflow as tf 
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense, Dropout
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# WARNING:tensorflow:From c:\Users\kshit\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kshit\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\kshit\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
file_path = 'intents_chatgpt.json'
with open(file_path, 'r') as file:
    data = json.load(file)

# %%
data
# Out:
# {'intents': [{'tag': 'greeting',
#    'patterns': ['Hi',
#     'Hey',
#     'How are you',
#     'Is anyone there?',
#     'Hello',
#     'Good day',
#     'Whats up',
#     'Whats cooking'],
#    'responses': ['Hello!',
#     'Good to see you again!',
#     'Hi there, how can I help?',
#     "Hello! I'm Dexter. How may I help you?",
#     'Hey there!'],
#    'context_set': ''},
#   {'tag': 'book_table',
#    'patterns': ['Book a table',
#     'Can I book a table?',
#     'I want to book a table',
#     'Book seat',
#     'I want to book a seat',
#     'Can I book a seat?'],
#    'responses': ["Sure, I can help you with that! Please provide me with the date and time you'd like to book."],
#    'context_set': ''},
#   {'tag': 'available_tables',
#    'patterns': ['How many seats are available?',
#     'Available seats',
#     'How many tables are available?',
#     'Available tables'],
#    'responses': ['We currently have X tables/seats available.'],
#    'context_set': ''},
#   {'tag': 'goodbye',
#    'patterns': ['cya',
#     'See you later',
#     'Goodbye',
#     'I am Leaving',
#     'Have a Good day',
#     'cya later',
#     'I gotta go now',
#     'I gotta rush now',
#     'bye bye',
#     'bye!'],
#    'responses': ['Sad to see you go :(', 'Talk to you later', 'Goodbye!'],
#    'context_set': ''},
#   {'tag': 'age',
#    'patterns': ['how old',
#     'how old is Dexter',
#     'what is your age',
#     'how old are you',
#     'age?'],
#    'responses': ['My master built me just a month ago.', 'Just a month old!'],
#    'context_set': ''},
#   {'tag': 'name',
#    'patterns': ['what is your name',
#     'what should I call you',
#     'whats your name?'],
#    'responses': ['You can call me Dexter.',
#     "I'm Dexter!",
#     "I'm Dexter aka The Restaurant Superbot."],
#    'context_set': ''},
#   {'tag': 'hours',
#    'patterns': ['when are you guys open',
#     'what are your hours',
#     'hours of operation',
#     'hours',
#     'what is the timing'],
#    'responses': ['We are open 10 am-12 am Monday-Friday!'],
#    'context_set': ''},
#   {'tag': 'menu',
#    'patterns': ['Id like to order something',
#     'whats on the menu',
#     'what do you recommend?',
#     'could I get something to eat',
#     "I'm hungry",
#     "Today's special?"],
#    'responses': ['Sure, what would you like?',
#     'Our menu includes a variety of dishes. What type of cuisine are you in the mood for?'],
#    'context_set': ''},
#   {'tag': 'contact',
#    'patterns': ['contact information',
#     'contact us',
#     'how can I contact you',
#     'can I get the contact details',
#     'I wanna give some feedback',
#     'how can I give some feedback?'],
#    'responses': ['You can contact us at contact@restaurantname.com'],
#    'context_set': ''},
#   {'tag': 'address',
#    'patterns': ['what is the location?',
#     'whats the location',
#     'where are you located?',
#     'where is the restaurant located?',
#     'address',
#     'whats the address?'],
#    'responses': ['You can locate us at Taj Lands End, Bandra Bandstand, Bandra West, Mumbai, Maharashtra 400 050'],
#    'context_set': ''},
#   {'tag': 'thanks',
#    'patterns': ['Thank you', 'Thanks', 'Thanks a lot', 'Thank you so much'],
#    'responses': ["You're welcome!",
#     'Glad I could assist you!',
#     'Anytime! If you have more questions, feel free to ask.'],
#    'context_set': ''},
#   {'tag': 'custom_order',
#    'patterns': ['Can I customize my order?',
#     'I have dietary restrictions',
#     'Do you offer vegan options?',
#     'Can I make substitutions?'],
#    'responses': ["Absolutely! We can accommodate custom orders. Please let us know your preferences, and we'll make it special for you."],
#    'context_set': ''},
#   {'tag': 'what_can_you_do',
#    'patterns': ['What can you do?',
#     'What services do you offer?',
#     'Can you help with reservations?',
#     'Tell me your capabilities'],
#    'responses': ['I can assist you with booking tables, providing information about our menu, restaurant hours, and address. Additionally, I can handle custom orders and help with general inquiries. If you have specific questions, feel free to ask!'],
#    'context_set': ''},
#   {'tag': 'weather',
#    'patterns': ["How's the weather today?",
#     'Tell me the weather',
#     "What's the weather like?"],
#    'responses': ["I'm sorry, but I'm not equipped to provide real-time weather updates. You may want to check a weather website or app for the latest information."],
#    'context_set': ''},
#   {'tag': 'random_fact',
#    'patterns': ['Tell me a random fact',
#     'Give me an interesting fact',
#     'Fascinate me with a fact'],
#    'responses': ['Sure! Did you know that honey never spoils? Archaeologists have found pots of honey in ancient Egyptian tombs that are over 3,000 years old and still perfectly edible.'],
#    'context_set': ''}]}

# %%
words =[]
classes =[]
data_x =[]
data_y =[]

for intent in data["intents"]:
    for pattern in intent["patterns"]:
        tokens = nltk.word_tokenize(pattern)
        words.extend(tokens)
        data_x.append(pattern)
        data_y.append(intent["tag"]),
        
    if intent["tag"] not in classes:
        classes.append(intent["tag"])

lemmatizer = WordNetLemmatizer()

words=[lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
words=sorted(set(words))
classes=sorted(set(classes))

# %%
training =[]
out_empty =[0]*len(classes)

for idx, doc in enumerate(data_x):
    bow=[]
    text=lemmatizer.lemmatize(doc.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)
        
    output_row=list(out_empty)
    output_row[classes.index(data_y[idx])]=1
    
    training.append([bow,output_row])
    
random.shuffle(training)
training=np.array(training,dtype=object)
train_x=np.array(list(training[:,0]))
train_y=np.array(list(training[:,1]))

# %%
model=Sequential()
model.add(Dense(128,input_shape=(len(train_x[0]),),activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64,activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]),activation="softmax"))
adam=tf.keras.optimizers.legacy.Adam(learning_rate=0.01,decay=1e-6)
model.compile(loss='categorical_crossentropy',optimizer=adam,metrics=["accuracy"])
print(model.summary())
model.fit(x=train_x,y=train_y,epochs=150,verbose=1)
# Out:
# WARNING:tensorflow:From c:\Users\kshit\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               14208
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 15)                975
#
# =================================================================
# Total params: 23439 (91.56 KB)
# Trainable params: 23439 (91.56 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/150
# WARNING:tensorflow:From c:\Users\kshit\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\kshit\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 3/3 [==============================] - 0s 5ms/step - loss: 2.8150 - accuracy: 0.0390
# Epoch 2/150
# 3/3 [==============================] - 0s 3ms/step - loss: 2.5000 - accuracy: 0.2338
# Epoch 3/150
# 3/3 [==============================] - 0s 3ms/step - loss: 2.3761 - accuracy: 0.3377
# Epoch 4/150
# 3/3 [==============================] - 0s 3ms/step - loss: 2.1747 - accuracy: 0.3636
# Epoch 5/150
# 3/3 [==============================] - 0s 3ms/step - loss: 1.9718 - accuracy: 0.4416
# Epoch 6/150
# 3/3 [==============================] - 0s 4ms/step - loss: 1.7731 - accuracy: 0.5195
# Epoch 7/150
# 3/3 [==============================] - 0s 3ms/step - loss: 1.4489 - accuracy: 0.6234
# Epoch 8/150
# 3/3 [==============================] - 0s 3ms/step - loss: 1.3704 - accuracy: 0.6104
# Epoch 9/150
# 3/3 [==============================] - 0s 3ms/step - loss: 1.1401 - accuracy: 0.6883
# Epoch 10/150
# 3/3 [==============================] - 0s 3ms/step - loss: 1.0817 - accuracy: 0.7143
# Epoch 11/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.9660 - accuracy: 0.7403
# Epoch 12/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7665 - accuracy: 0.8182
# Epoch 13/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7356 - accuracy: 0.7662
# Epoch 14/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5440 - accuracy: 0.8442
# Epoch 15/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5409 - accuracy: 0.7922
# Epoch 16/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5250 - accuracy: 0.8312
# Epoch 17/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4255 - accuracy: 0.8701
# Epoch 18/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5316 - accuracy: 0.8701
# Epoch 19/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3224 - accuracy: 0.9221
# Epoch 20/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3315 - accuracy: 0.8701
# Epoch 21/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3873 - accuracy: 0.8312
# Epoch 22/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3718 - accuracy: 0.8961
# Epoch 23/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2172 - accuracy: 0.9351
# Epoch 24/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1299 - accuracy: 0.9870
# Epoch 25/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2577 - accuracy: 0.9351
# Epoch 26/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2742 - accuracy: 0.8961
# Epoch 27/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3323 - accuracy: 0.8961
# Epoch 28/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2587 - accuracy: 0.9610
# Epoch 29/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1460 - accuracy: 0.9870
# Epoch 30/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1350 - accuracy: 0.9740
# Epoch 31/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1708 - accuracy: 0.9740
# Epoch 32/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1125 - accuracy: 0.9870
# Epoch 33/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1552 - accuracy: 0.9610
# Epoch 34/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1816 - accuracy: 0.9481
# Epoch 35/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1666 - accuracy: 0.9481
# Epoch 36/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1126 - accuracy: 0.9610
# Epoch 37/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1465 - accuracy: 0.9610
# Epoch 38/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1172 - accuracy: 0.9351
# Epoch 39/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1834 - accuracy: 0.9091
# Epoch 40/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1931 - accuracy: 0.9481
# Epoch 41/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0528 - accuracy: 0.9870
# Epoch 42/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0833 - accuracy: 0.9870
# Epoch 43/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2136 - accuracy: 0.9351
# Epoch 44/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0847 - accuracy: 0.9740
# Epoch 45/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2209 - accuracy: 0.9351
# Epoch 46/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0917 - accuracy: 0.9740
# Epoch 47/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1649 - accuracy: 0.9351
# Epoch 48/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0980 - accuracy: 0.9740
# Epoch 49/150
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1488 - accuracy: 0.9481
# Epoch 50/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0552 - accuracy: 0.9870
# Epoch 51/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1122 - accuracy: 0.9610
# Epoch 52/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1369 - accuracy: 0.9740
# Epoch 53/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1077 - accuracy: 0.9740
# Epoch 54/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1142 - accuracy: 0.9610
# Epoch 55/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0844 - accuracy: 0.9740
# Epoch 56/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0782 - accuracy: 0.9740
# Epoch 57/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0926 - accuracy: 0.9740
# Epoch 58/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1302 - accuracy: 0.9481
# Epoch 59/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0917 - accuracy: 0.9740
# Epoch 60/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1332 - accuracy: 0.9740
# Epoch 61/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0886 - accuracy: 0.9740
# Epoch 62/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9870
# Epoch 63/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1743 - accuracy: 0.9351
# Epoch 64/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0580 - accuracy: 0.9870
# Epoch 65/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0700 - accuracy: 0.9870
# Epoch 66/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1245 - accuracy: 0.9610
# Epoch 67/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0641 - accuracy: 0.9870
# Epoch 68/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1658 - accuracy: 0.9610
# Epoch 69/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1204 - accuracy: 0.9740
# Epoch 70/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0907 - accuracy: 0.9740
# Epoch 71/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0692 - accuracy: 0.9740
# Epoch 72/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1492 - accuracy: 0.9481
# Epoch 73/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1414 - accuracy: 0.9740
# Epoch 74/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0648 - accuracy: 0.9870
# Epoch 75/150
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0763 - accuracy: 0.9740
# Epoch 76/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0379 - accuracy: 0.9870
# Epoch 77/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1543 - accuracy: 0.9351
# Epoch 78/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0611 - accuracy: 0.9870
# Epoch 79/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0615 - accuracy: 0.9870
# Epoch 80/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1037 - accuracy: 0.9740
# Epoch 81/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1187 - accuracy: 0.9740
# Epoch 82/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0639 - accuracy: 0.9740
# Epoch 83/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0980 - accuracy: 0.9610
# Epoch 84/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0561 - accuracy: 0.9870
# Epoch 85/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0505 - accuracy: 0.9870
# Epoch 86/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0925 - accuracy: 0.9610
# Epoch 87/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0320 - accuracy: 0.9870
# Epoch 88/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0506 - accuracy: 0.9740
# Epoch 89/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1097 - accuracy: 0.9610
# Epoch 90/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0598 - accuracy: 0.9870
# Epoch 91/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0776 - accuracy: 0.9740
# Epoch 92/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0455 - accuracy: 0.9870
# Epoch 93/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 94/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0473 - accuracy: 0.9870
# Epoch 95/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 96/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0932 - accuracy: 0.9610
# Epoch 97/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 98/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0655 - accuracy: 0.9740
# Epoch 99/150
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 100/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0429 - accuracy: 0.9870
# Epoch 101/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0788 - accuracy: 0.9870
# Epoch 102/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0848 - accuracy: 0.9740
# Epoch 103/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0586 - accuracy: 0.9870
# Epoch 104/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0572 - accuracy: 0.9870
# Epoch 105/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 106/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1448 - accuracy: 0.9610
# Epoch 107/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1086 - accuracy: 0.9610
# Epoch 108/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0300 - accuracy: 1.0000
# Epoch 109/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0705 - accuracy: 0.9740
# Epoch 110/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0483 - accuracy: 0.9870
# Epoch 111/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0577 - accuracy: 0.9870
# Epoch 112/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1012 - accuracy: 0.9870
# Epoch 113/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0248 - accuracy: 1.0000
# Epoch 114/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0268 - accuracy: 1.0000
# Epoch 115/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 116/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0337 - accuracy: 0.9870
# Epoch 117/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0901 - accuracy: 0.9610
# Epoch 118/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0616 - accuracy: 0.9740
# Epoch 119/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0255 - accuracy: 0.9870
# Epoch 120/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0448 - accuracy: 0.9740
# Epoch 121/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0271 - accuracy: 0.9870
# Epoch 122/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0384 - accuracy: 0.9870
# Epoch 123/150
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 124/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0513 - accuracy: 0.9740
# Epoch 125/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0335 - accuracy: 0.9870
# Epoch 126/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0533 - accuracy: 0.9870
# Epoch 127/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0334 - accuracy: 0.9870
# Epoch 128/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 129/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 0.9870
# Epoch 130/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0296 - accuracy: 0.9870
# Epoch 131/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0685 - accuracy: 0.9610
# Epoch 132/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0644 - accuracy: 0.9610
# Epoch 133/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 134/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 135/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0500 - accuracy: 0.9870
# Epoch 136/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 137/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0640 - accuracy: 0.9740
# Epoch 138/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 139/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 140/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0782 - accuracy: 0.9870
# Epoch 141/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0932 - accuracy: 0.9740
# Epoch 142/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0226 - accuracy: 0.9870
# Epoch 143/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0347 - accuracy: 0.9870
# Epoch 144/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0488 - accuracy: 0.9870
# Epoch 145/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0360 - accuracy: 0.9870
# Epoch 146/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1421 - accuracy: 0.9610
# Epoch 147/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0728 - accuracy: 0.9740
# Epoch 148/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1057 - accuracy: 0.9481
# Epoch 149/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1670 - accuracy: 0.9481
# Epoch 150/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0620 - accuracy: 0.9870

# %%
def clean_text(text):
    tokens = nltk.word_tokenize(text)
    tokens =[lemmatizer.lemmatize(word) for word in tokens]
    return tokens

def bag_of_words(text,vocab):
    tokens=clean_text(text)
    bow=[0]*len(vocab)
    for w in tokens:
        for idx, word in enumerate(vocab):
            if word ==w:
                bow[idx]=1
    return np.array(bow)

def pred_class(text,vocab,labels):
    bow=bag_of_words(text,vocab)
    result = model.predict(np.array([bow]))[0]
    thresh =0.5
    y_pred=[[indx,res] for indx, res in enumerate(result) if res > thresh]
    y_pred.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in y_pred:
        return_list.append(labels[r[0]])
    return return_list

def get_response(intents_list, intents_json):
    if len(intents_list)==0:
        result ="Sorry! I don't understand."
    else:
        tag=intents_list[0]
        list_of_intents=intents_json["intents"]
        for i in list_of_intents:
            if i["tag"]==tag:
                result = random.choice(i["responses"])
                break
    return result

# %%
model.save("chatbot_model.h5")
# Out:
# c:\Users\kshit\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
print("Press 0 if you don't want to chat with our ChatBot.")
while True: 
    message = input("")
    if message == "0":
        break
    intents = pred_class(message,words,classes)
    result = get_response(intents,data)
    print(result)
# Out:
# Press 0 if you don't want to chat with our ChatBot.
# 1/1 [==============================] - 0s 71ms/step
# Hello! I'm Dexter. How may I help you?
